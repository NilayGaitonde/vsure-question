# %%
import torch
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from PIL import Image, ImageDraw, ImageFont

# %%
def load_model():
    model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
    return model
model = load_model()
load_img = "imgs/Photo on 21-03-24 at 16.07.jpg"
results = model(load_img)
results.show()
for obj in results.xyxy[0]:
    confidence = obj[4].item() * 100
    label = model.names[int(obj[5])]
    print(f'{label}: {confidence:.2f}%')
# Out:
# Using cache found in /Users/nilaygaitonde/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-3-19 Python-3.10.13 torch-2.2.2 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1200x800>
# vase: 41.08%
# bottle: 38.53%
# bowl: 31.18%
# cup: 28.03%

# %%
results.xyxy[0]
# Out:
# tensor([[7.08766e+02, 6.56374e+02, 7.76159e+02, 7.31215e+02, 4.10778e-01, 7.50000e+01],
#         [6.09695e+02, 6.49360e+02, 6.55510e+02, 7.31350e+02, 3.85340e-01, 3.90000e+01],
#         [4.36360e+02, 7.07071e+02, 5.04407e+02, 7.44764e+02, 3.11802e-01, 4.50000e+01],
#         [6.09247e+02, 6.50301e+02, 6.56566e+02, 7.30095e+02, 2.80263e-01, 4.10000e+01]])
